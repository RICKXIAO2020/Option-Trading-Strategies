# %%
# -*- coding: utf-8 -*-
#先引入后面分析、可视化等可能用到的库
import tushare as ts

import pandas as pd  
import matplotlib.pyplot as plt
#正常显示画图时出现的中文和负号
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

#设置token
token='ffc714ffff21ebeaac6ef3cbf0db7bd557634cdaf1c5cc95afb0f35e'
#ts.set_token(token)
pro = ts.pro_api(token)

#获取当前上市的股票代码、简称、注册地、行业、上市时间等数据
basic=pro.stock_basic(list_status='L')
#查看前五行数据
#basic.head(5)

#获取平安银行日行情数据
pa=pro.daily(ts_code='000001.SZ', start_date='20180101',
               end_date='20190106')
#pa.head()

#K线图可视化
from pyecharts import Kline
pa.index=pd.to_datetime(pa.trade_date)
pa=pa.sort_index()
v1=list(pa.loc[:,['open','close','low','high']].values)
t=pa.index
v0=list(t.strftime('%Y%m%d'))
kline = Kline("平安银行K线图",title_text_size=15)
kline.add("", v0, v1,is_datazoom_show=True,
         mark_line=["average"],
         mark_point=["max", "min"],
         mark_point_symbolsize=60,
         mark_line_valuedim=['highest', 'lowest'] )
#kline.render("上证指数图.html")

kline
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ff00c31c3ec246249b3ea28c6fcf5764" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ff00c31c3ec246249b3ea28c6fcf5764 = echarts.init(document.getElementById('ff00c31c3ec246249b3ea28c6fcf5764'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_ff00c31c3ec246249b3ea28c6fcf5764 = {
#     "title": [
#         {
#             "text": "\u5e73\u5b89\u94f6\u884cK\u7ebf\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 15
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1335341,
#     "tooltip": {
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": kline_tooltip_formatter,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "candlestick",
#             "data": [
#                 [
#                     13.35,
#                     13.7,
#                     13.32,
#                     13.93
#                 ],
#                 [
#                     13.73,
#                     13.33,
#                     13.2,
#                     13.86
#                 ],
#                 [
#                     13.32,
#                     13.25,
#                     13.13,
#                     13.37
#                 ],
#                 [
#                     13.21,
#                     13.3,
#                     13.15,
#                     13.35
#                 ],
#                 [
#                     13.25,
#                     12.96,
#                     12.86,
#                     13.29
#                 ],
#                 [
#                     12.96,
#                     13.08,
#                     12.92,
#                     13.2
#                 ],
#                 [
#                     13.04,
#                     13.47,
#                     12.92,
#                     13.49
#                 ],
#                 [
#                     13.41,
#                     13.4,
#                     13.27,
#                     13.59
#                 ],
#                 [
#                     13.45,
#                     13.55,
#                     13.41,
#                     13.68
#                 ],
#                 [
#                     13.51,
#                     14.2,
#                     13.5,
#                     14.33
#                 ],
#                 [
#                     14.17,
#                     14.2,
#                     14.02,
#                     14.38
#                 ],
#                 [
#                     14.33,
#                     14.23,
#                     14.2,
#                     14.8
#                 ],
#                 [
#                     14.4,
#                     14.72,
#                     14.28,
#                     14.72
#                 ],
#                 [
#                     14.8,
#                     14.8,
#                     14.68,
#                     15.13
#                 ],
#                 [
#                     14.6,
#                     14.44,
#                     14.43,
#                     14.94
#                 ],
#                 [
#                     14.36,
#                     14.65,
#                     14.33,
#                     14.9
#                 ],
#                 [
#                     14.66,
#                     14.64,
#                     14.5,
#                     15.08
#                 ],
#                 [
#                     14.45,
#                     14.2,
#                     14.0,
#                     14.47
#                 ],
#                 [
#                     14.18,
#                     14.05,
#                     14.02,
#                     14.34
#                 ],
#                 [
#                     14.05,
#                     13.74,
#                     13.6,
#                     14.25
#                 ],
#                 [
#                     13.7,
#                     13.65,
#                     13.55,
#                     13.84
#                 ],
#                 [
#                     13.6,
#                     14.05,
#                     13.53,
#                     14.05
#                 ],
#                 [
#                     13.95,
#                     14.03,
#                     13.84,
#                     14.3
#                 ],
#                 [
#                     13.91,
#                     14.05,
#                     13.63,
#                     14.1
#                 ],
#                 [
#                     13.8,
#                     14.55,
#                     13.73,
#                     14.57
#                 ],
#                 [
#                     14.23,
#                     14.0,
#                     13.93,
#                     14.33
#                 ],
#                 [
#                     14.22,
#                     12.92,
#                     12.76,
#                     14.3
#                 ],
#                 [
#                     12.83,
#                     12.54,
#                     12.53,
#                     12.92
#                 ],
#                 [
#                     12.08,
#                     11.69,
#                     11.38,
#                     12.08
#                 ],
#                 [
#                     11.78,
#                     11.72,
#                     11.56,
#                     11.84
#                 ],
#                 [
#                     11.87,
#                     11.94,
#                     11.84,
#                     12.21
#                 ],
#                 [
#                     11.96,
#                     12.0,
#                     11.76,
#                     12.03
#                 ],
#                 [
#                     12.25,
#                     12.46,
#                     12.25,
#                     12.53
#                 ],
#                 [
#                     12.58,
#                     12.61,
#                     12.45,
#                     12.79
#                 ],
#                 [
#                     12.77,
#                     12.63,
#                     12.45,
#                     12.85
#                 ],
#                 [
#                     12.64,
#                     12.28,
#                     12.19,
#                     12.7
#                 ],
#                 [
#                     12.1,
#                     12.05,
#                     11.93,
#                     12.19
#                 ],
#                 [
#                     11.92,
#                     12.04,
#                     11.9,
#                     12.15
#                 ],
#                 [
#                     11.92,
#                     11.95,
#                     11.85,
#                     12.04
#                 ],
#                 [
#                     11.93,
#                     11.86,
#                     11.8,
#                     12.08
#                 ],
#                 [
#                     11.95,
#                     12.1,
#                     11.77,
#                     12.11
#                 ],
#                 [
#                     12.15,
#                     12.0
