# %%
import rqdatac as rq 
from rqdatac import * 
rq.init()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\rqdatac\client.py:231: UserWarning: Your account will be expired after  11 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   "renew your contract.".format(remaining_days))

# %%
all_instruments("CS")
# Out:
#      order_book_id industry_code  market_tplus symbol special_type exchange  \
# 0      000002.XSHE           K70             1    万科A       Normal     XSHE
# 1      000005.XSHE           N77             1   世纪星源       Normal     XSHE
# 2      000028.XSHE           F51             1   国药一致       Normal     XSHE
# 3      000006.XSHE           K70             1   深振业A       Normal     XSHE
# 4      000024.XSHE       Unknown             1   招商地产       Normal     XSHE
# ...            ...           ...           ...    ...          ...      ...
# 4259   688678.XSHG           C34             1    福立旺       Normal     XSHG
# 4260   300919.XSHE           C39             1   中伟股份       Normal     XSHE
# 4261   688560.XSHG           C29             1   明冠新材       Normal     XSHG
# 4262   688679.XSHG           N77             1   通源环境       Normal     XSHG
# 4263   688658.XSHG           C27             1   悦康药业       Normal     XSHG
#
# ...

# %%
rq.info()
# Out:
# rqdatac version: 2.9.17
# server address: rqdatad-pro.ricequant.com:16011
# You are using license:
# KF1R9hTE67n9A99pnRFLhZp4I_k-GSU5nCAXaSrnVT2lS07oaFxITQ8KLsePBawcizdUgcRtxO8fyPfN3pZOBUJI7PJPY4YeqgMMIJxsmDTuBkuTIUXhF0HEh6vunNKGo6u7jzSywedn0CVdx-MRJUKqn3fGakUMax9W3yY8bxs=blMNgF-Wyoevx4cy4nEizqcR4gtM50nGyEK1iBda-c_xuK-Cq6KNVwiJCXsn6f4WlnikPwXLKyzCsbYkQf-4-W1_Z-vvpVytwnzVGRTdDOmKkDgsf3kJzhHWMwD36ThQpzX7Nhbv0ce60W_Rx-L-2fZjRY0tMqtQ3yU0mPpUWrc=

# %%
index_components("000016.XSHG")
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-7-738464cac7e7> in <module>
# ----> 1 index_components("000016.XSHG")
#
# C:\ProgramData\Anaconda3\lib\site-packages\rqdatac\decorators.py in wrap(*args, **kwargs)
#     129                 if item != value:
#     130                     raise ValueError("'{}': except '{}', got '{}'".format(name, value, item))
# --> 131         return func(*args, **kwargs)
#     132
#     133     return wrap
#
# C:\ProgramData\Anaconda3\lib\site-packages\rqdatac\services\index.py in index_components(order_book_id, date, start_date, end_date, market)
#      54     if date:
#      55         date = ensure_date_int(date)
# ---> 56     return get_client().execute("index_components", order_book_id, date, market=market)
#      57
#      58
#
# C:\ProgramData\Anaconda3\lib\site-packages\rqdatac\decorators.py in wrap(*args, **kwargs)
# ...
